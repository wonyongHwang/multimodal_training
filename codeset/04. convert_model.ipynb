# %%
try:
    import google.colab
    inColab = True
except ImportError:
    inColab = False
if inColab == True:
    from google.colab import drive
    drive.mount("/content/gdrive")

# %%
### ★★★ 수정 포인트 ★★★ 
# 코드의 위치 로 이동
if inColab == True:
    # %cd /content/gdrive/MyDrive/Colab Notebooks/ggufs

# %%
### HF TO SNAPSHOT
### ★★★ 수정 포인트 ★★★
from huggingface_hub import snapshot_download
# 현재 폴더 기준 gdownPath 폴더가 생성되고 허깅페이스의 model_id 이름의 모델이 다운로드 됨
gdownPath = "kopo_gemma3_4b"
# 불러올 허깅페이스모델 (model_id 변수에 할당)
model_id="hyokwan/kopo_gemma3_4b_fintech"

# %%
# 현재 폴더 기준 폴더 생성
# 구글드라이브에 이미 있으면 두번 실행할 필요는 없다!
snapshot_download(repo_id=model_id, local_dir=gdownPath,
                  revision="main", max_workers=4)
# Setup Llama.cpp and install required packages
# Out:
# ...
# Fetching 11 files:   0%|          | 0/11 [00:00<?, ?it/s]

# %%
# # 구글드라이브에 이미 있으면 두번 실행할 필요는 없다!
# !git clone https://github.com/ggerganov/llama.cpp
# !pip install -r llama.cpp/requirements.txt
# Out:
# Cloning into 'llama.cpp'...
# Updating files:  58% (1504/2567)
# Updating files:  59% (1515/2567)
# Updating files:  60% (1541/2567)
# Updating files:  61% (1566/2567)
# Updating files:  62% (1592/2567)
# Updating files:  63% (1618/2567)
# Updating files:  64% (1643/2567)
# Updating files:  65% (1669/2567)
# Updating files:  66% (1695/2567)
# Updating files:  67% (1720/2567)
# Updating files:  68% (1746/2567)
# Updating files:  69% (1772/2567)
# Updating files:  70% (1797/2567)
# Updating files:  71% (1823/2567)
# Updating files:  72% (1849/2567)
# Updating files:  73% (1874/2567)
# Updating files:  74% (1900/2567)
# Updating files:  75% (1926/2567)
# Updating files:  76% (1951/2567)
# Updating files:  77% (1977/2567)
# Updating files:  78% (2003/2567)
# Updating files:  79% (2028/2567)
# Updating files:  80% (2054/2567)
# Updating files:  81% (2080/2567)
# Updating files:  82% (2105/2567)
# Updating files:  83% (2131/2567)
# Updating files:  84% (2157/2567)
# ...

# %%
####### ★★★ 수정 포인트★★★ ############
# !python llama.cpp/convert_hf_to_gguf.py [파인튜닝모델 다운로드 폴더위치] --outfile [GGUF 파일명].gguf --outtype {f32, f16, bf16, q8_0, auto} --vocab-type bpe
# !python llama.cpp/convert_hf_to_gguf.py kopo_gemma3_4b_fintech_slow --outfile gemma3_4b_kopo_fintech.gguf --outtype f16
# Out:
# usage: convert_hf_to_gguf.py [-h] [--vocab-only] [--outfile OUTFILE]
#                              [--outtype {f32,f16,bf16,q8_0,tq1_0,tq2_0,auto}]
#                              [--bigendian] [--use-temp-file] [--no-lazy]
#                              [--model-name MODEL_NAME] [--verbose]
#                              [--split-max-tensors SPLIT_MAX_TENSORS]
#                              [--split-max-size SPLIT_MAX_SIZE] [--dry-run]
#                              [--no-tensor-first-split] [--metadata METADATA]
#                              [--print-supported-models] [--remote] [--mmproj]
#                              [--mistral-format]
#                              [--disable-mistral-community-chat-template]
#                              [--sentence-transformers-dense-modules]
#                              [--fuse-gate-up-exps]
#                              [model]
# convert_hf_to_gguf.py: error: unrecognized arguments: --vocab-type bpe

# %%
from huggingface_hub import HfApi
api = HfApi()

####### ★★★ 수정 포인트★★★ ############
# gguf 파일 경로
file_path = "familidata_gemma3_4b_elysium.gguf"

# Hugging Face 저장소 이름
repo_name = "hyokwan/familidata_elysium_gguf"

# 파일 업로드
api.upload_file(
    path_or_fileobj=file_path,
    path_in_repo="familidata_gemma3_4b_elysium.gguf",  # 저장소 내 파일 경로
    repo_id=repo_name,
    repo_type="model",  # 모델 저장소에 업로드
)
